# %% [markdown]
# # Covid 19 Data Analysis from Brasil.io
# This is a personal project where I tried to create an analysis of Brasil.io Covid-19 dataset
#
# Date: 21/05/2020

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Opening CSV file with pandas
data = pd.read_csv('caso.csv')
print(data)

# print(data['state'].nunique())
# Out:
#              date state            city place_type  confirmed  deaths  \
# 0      2020-05-18    SE             NaN      state       3566      59
# 1      2020-05-17    SE             NaN      state       3343      57
# 2      2020-05-16    SE             NaN      state       3135      53
# 3      2020-05-15    SE             NaN      state       2868      50
# 4      2020-05-14    SE             NaN      state       2494      47
# 5      2020-05-13    SE             NaN      state       2268      42
# 6      2020-05-12    SE             NaN      state       2032      37
# 7      2020-05-11    SE             NaN      state       1800      37
# 8      2020-05-10    SE             NaN      state       1771      34
# 9      2020-05-09    SE             NaN      state       1588      33
# 10     2020-05-08    SE             NaN      state       1438      28
# 11     2020-05-07    SE             NaN      state       1214      25
# 12     2020-05-06    SE             NaN      state        998      23
# 13     2020-05-05    SE             NaN      state        898      21
# 14     2020-05-04    SE             NaN      state        772      17
# 15     2020-05-03    SE             NaN      state        730      14
# 16     2020-05-02    SE             NaN      state        601      14
# 17     2020-05-01    SE             NaN      state        517      14
# 18     2020-04-30    SE             NaN      state        453      14
# 19     2020-04-28    SE             NaN      state        280      11
# 20     2020-04-27    SE             NaN      state        211      11
# 21     2020-04-26    SE             NaN      state        175       9
# 22     2020-04-25    SE             NaN      state        154       9
# 23     2020-04-24    SE             NaN      state        145       8
# 24     2020-04-23    SE             NaN      state        135       8
# 25     2020-04-22    SE             NaN      state        118       7
# 26     2020-04-21    SE             NaN      state        117       7
# 27     2020-04-20    SE             NaN      state         92       5
# 28     2020-04-19    SE             NaN      state         86       5
# 29     2020-04-18    SE             NaN      state         71       5
# ...           ...   ...             ...        ...        ...     ...
# 92674  2020-05-15    BA  Várzea da Roça       city          1       0
# 92675  2020-05-14    BA  Várzea da Roça       city          1       0
# 92676  2020-05-18    BA       Água Fria       city          2       1
# 92677  2020-05-17    BA       Água Fria       city          2       1
# 92678  2020-05-16    BA       Água Fria       city          2       1
# 92679  2020-05-15    BA       Água Fria       city          1       1
# 92680  2020-05-14    BA       Água Fria       city          1       1
# 92681  2020-05-13    BA       Água Fria       city          1       1
# 92682  2020-05-12    BA       Água Fria       city          1       1
# 92683  2020-05-11    BA       Água Fria       city          1       1
# 92684  2020-05-10    BA       Água Fria       city          1       1
# 92685  2020-05-09    BA       Água Fria       city          1       1
# 92686  2020-05-08    BA       Água Fria       city          1       1
# 92687  2020-05-07    BA       Água Fria       city          1       1
# 92688  2020-05-06    BA       Água Fria       city          1       1
# 92689  2020-05-05    BA       Água Fria       city          1       1
# 92690  2020-05-04    BA       Água Fria       city          1       1
# 92691  2020-05-03    BA       Água Fria       city          1       1
# 92692  2020-05-02    BA       Água Fria       city          1       1
# 92693  2020-05-01    BA       Água Fria       city          1       1
# 92694  2020-04-30    BA       Água Fria       city          1       1
# 92695  2020-04-29    BA       Água Fria       city          1       1
# 92696  2020-04-28    BA       Água Fria       city          1       1
# 92697  2020-04-27    BA       Água Fria       city          1       1
# 92698  2020-04-26    BA       Água Fria       city          1       1
# 92699  2020-04-25    BA       Água Fria       city          1       1
# 92700  2020-04-24    BA       Água Fria       city          1       1
# 92701  2020-04-23    BA       Água Fria       city          1       1
# 92702  2020-04-22    BA       Água Fria       city          0       1
# 92703  2020-04-21    BA       Água Fria       city          0       1
#
#        order_for_place  is_last  estimated_population_2019  city_ibge_code  \
# 0                   55     True                  2298696.0            28.0
# 1                   54    False                  2298696.0            28.0
# 2                   53    False                  2298696.0            28.0
# 3                   52    False                  2298696.0            28.0
# 4                   51    False                  2298696.0            28.0
# 5                   50    False                  2298696.0            28.0
# 6                   49    False                  2298696.0            28.0
# 7                   48    False                  2298696.0            28.0
# 8                   47    False                  2298696.0            28.0
# 9                   46    False                  2298696.0            28.0
# 10                  45    False                  2298696.0            28.0
# 11                  44    False                  2298696.0            28.0
# 12                  43    False                  2298696.0            28.0
# 13                  42    False                  2298696.0            28.0
# 14                  41    False                  2298696.0            28.0
# 15                  40    False                  2298696.0            28.0
# 16                  39    False                  2298696.0            28.0
# 17                  38    False                  2298696.0            28.0
# 18                  37    False                  2298696.0            28.0
# 19                  36    False                  2298696.0            28.0
# 20                  35    False                  2298696.0            28.0
# 21                  34    False                  2298696.0            28.0
# 22                  33    False                  2298696.0            28.0
# 23                  32    False                  2298696.0            28.0
# 24                  31    False                  2298696.0            28.0
# 25                  30    False                  2298696.0            28.0
# 26                  29    False                  2298696.0            28.0
# 27                  28    False                  2298696.0            28.0
# 28                  27    False                  2298696.0            28.0
# 29                  26    False                  2298696.0            28.0
# ...                ...      ...                        ...             ...
# 92674                2    False                    14104.0       2933059.0
# 92675                1    False                    14104.0       2933059.0
# 92676               28     True                    16970.0       2900405.0
# 92677               27    False                    16970.0       2900405.0
# 92678               26    False                    16970.0       2900405.0
# 92679               25    False                    16970.0       2900405.0
# 92680               24    False                    16970.0       2900405.0
# 92681               23    False                    16970.0       2900405.0
# 92682               22    False                    16970.0       2900405.0
# 92683               21    False                    16970.0       2900405.0
# 92684               20    False                    16970.0       2900405.0
# 92685               19    False                    16970.0       2900405.0
# 92686               18    False                    16970.0       2900405.0
# 92687               17    False                    16970.0       2900405.0
# 92688               16    False                    16970.0       2900405.0
# 92689               15    False                    16970.0       2900405.0
# 92690               14    False                    16970.0       2900405.0
# 92691               13    False                    16970.0       2900405.0
# 92692               12    False                    16970.0       2900405.0
# 92693               11    False                    16970.0       2900405.0
# 92694               10    False                    16970.0       2900405.0
# 92695                9    False                    16970.0       2900405.0
# 92696                8    False                    16970.0       2900405.0
# 92697                7    False                    16970.0       2900405.0
# 92698                6    False                    16970.0       2900405.0
# 92699                5    False                    16970.0       2900405.0
# 92700                4    False                    16970.0       2900405.0
# 92701                3    False                    16970.0       2900405.0
# 92702                2    False                    16970.0       2900405.0
# 92703                1    False                    16970.0       2900405.0
#
#        confirmed_per_100k_inhabitants  death_rate
# 0                           155.13143      0.0165
# 1                           145.43028      0.0171
# 2                           136.38167      0.0169
# 3                           124.76639      0.0174
# 4                           108.49630      0.0188
# 5                            98.66463      0.0185
# 6                            88.39794      0.0182
# 7                            78.30527      0.0206
# 8                            77.04368      0.0192
# 9                            69.08265      0.0208
# 10                           62.55721      0.0195
# 11                           52.81255      0.0206
# 12                           43.41592      0.0230
# 13                           39.06563      0.0234
# 14                           33.58426      0.0220
# 15                           31.75714      0.0192
# 16                           26.14526      0.0233
# 17                           22.49101      0.0271
# 18                           19.70683      0.0309
# 19                           12.18082      0.0393
# 20                            9.17912      0.0521
# 21                            7.61301      0.0514
# 22                            6.69945      0.0584
# 23                            6.30792      0.0552
# 24                            5.87289      0.0593
# 25                            5.13335      0.0593
# 26                            5.08984      0.0598
# 27                            4.00227      0.0543
# 28                            3.74125      0.0581
# 29                            3.08871      0.0704
# ...                               ...         ...
# 92674                         7.09019      0.0000
# 92675                         7.09019      0.0000
# 92676                        11.78550      0.5000
# 92677                        11.78550      0.5000
# 92678                        11.78550      0.5000
# 92679                         5.89275      1.0000
# 92680                         5.89275      1.0000
# 92681                         5.89275      1.0000
# 92682                         5.89275      1.0000
# 92683                         5.89275      1.0000
# 92684                         5.89275      1.0000
# 92685                         5.89275      1.0000
# 92686                         5.89275      1.0000
# 92687                         5.89275      1.0000
# 92688                         5.89275      1.0000
# 92689                         5.89275      1.0000
# 92690                         5.89275      1.0000
# 92691                         5.89275      1.0000
# 92692                         5.89275      1.0000
# 92693                         5.89275      1.0000
# 92694                         5.89275      1.0000
# 92695                         5.89275      1.0000
# 92696                         5.89275      1.0000
# 92697                         5.89275      1.0000
# 92698                         5.89275      1.0000
# 92699                         5.89275      1.0000
# 92700                         5.89275      1.0000
# 92701                         5.89275      1.0000
# 92702                             NaN      0.0000
# 92703                             NaN      0.0000
#
# [92704 rows x 12 columns]

# %%
per_state = data.groupby('state')['deaths'].max()
per_state = per_state.sort_values()
# print(per_state.sort_values())

per_state.plot('bar')

plt.xticks(size=30)
plt.yticks(size=30)
plt.title("Deaths by Covid-19 per State",size=40)
plt.xlabel("State", size=30)
plt.ylabel("Number of Deaths", size=30)

plt.savefig("deaths-per-state.png", dpi=100)
plt.show()
# Out:
# state
# MS      16
# MT      30
# TO      32
# RR      51
# SE      59
# AC      59
# DF      66
# GO      73
# RO      83
# SC      85
# PI      85
# AP     127
# PR     130
# RN     136
# RS     151
# MG     161
# PB     207
# AL     221
# ES     302
# BA     312
# MA     604
# PA    1392
# AM    1433
# PE    1640
# CE    1641
# RJ    2852
# SP    4823
# Name: deaths, dtype: int64

# %%
per_state.sort_values(ascending=False)
# per_state.sum()
# Out:
# state
# SP    4823
# RJ    2852
# CE    1641
# PE    1640
# AM    1433
# PA    1392
# MA     604
# BA     312
# ES     302
# AL     221
# PB     207
# MG     161
# RS     151
# RN     136
# PR     130
# AP     127
# PI      85
# SC      85
# RO      83
# GO      73
# DF      66
# AC      59
# SE      59
# RR      51
# TO      32
# MT      30
# MS      16
# Name: deaths, dtype: int64

# %%
state = data.loc()
